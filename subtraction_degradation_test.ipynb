# %% [markdown]
# ### load spike times and EI positions

# %%
import h5py
import numpy as np

# --- Parameters ---
dat_path = '/Volumes/Lab/Users/alexth/axolotl/201703151_data001.dat'  # Update this
h5_in_path = '/Volumes/Lab/Users/alexth/axolotl/201703151_kilosort_data001_spike_times.h5'  # from MATLAB export

sampling_rate = 20000  # Hz

# --- Load spike times from HDF5 ---
all_spikes = {}
with h5py.File(h5_in_path, 'r') as f:
    unit_ids = sorted(f['/spikes'].keys(), key=lambda x: int(x.split('_')[1]))
    for uid in unit_ids:
        unit_index = int(uid.split('_')[1])
        raw = f[f'/spikes/{uid}'][:]
        if raw.ndim == 1 and raw.shape[0] == 1:
            spikes_sec = np.array(raw[0]).flatten()
        else:
            spikes_sec = np.array(raw).flatten()
        spikes_samples = np.round(spikes_sec * sampling_rate).astype(np.int32)
        all_spikes[unit_index] = spikes_samples

    # Load electrode positions
    ei_positions = f['/ei_positions'][:].T  # shape becomes [512 x 2]

# %% [markdown]
# ### load parasol list from mat file

# %%
import scipy.io

mat_path = '/Volumes/Lab/Users/alexth/axolotl/parasol_list_data001.mat'
mat_contents = scipy.io.loadmat(mat_path)

parasol_list = mat_contents['parasol_list'].squeeze()

# %% [markdown]
# ### order parasol list by EI amplitude

# %%
import h5py
import numpy as np

h5_ei_path = '/Volumes/Lab/Users/alexth/axolotl/ks_eis_subset.h5'

ks_templates = {}
with h5py.File(h5_ei_path, 'r') as f:
    for k in f.keys():
        ks_templates[int(k.split('_')[1])] = f[k][:]
ks_unit_ids = list(ks_templates.keys())
ks_ei_stack = np.stack([ks_templates[k] for k in ks_unit_ids], axis=0)  # [N x 512 x 81]

# Compute peak-to-peak per channel, per unit
peak_to_peak = ks_ei_stack.max(axis=2) - ks_ei_stack.min(axis=2)  # shape: [N x 512]

# Get maximum value across all channels per unit
unit_max_amp = peak_to_peak.max(axis=1)  # shape: [N]

# Get sorting indices (descending)
sorted_indices = np.argsort(unit_max_amp)[::-1]

# Reorder unit IDs by amplitude
ks_unit_ids_sorted = [ks_unit_ids[i] for i in sorted_indices]
unit_max_amp_sorted = unit_max_amp[sorted_indices]

# Filter sorted KS IDs to keep only those in parasol_list
parasol_set = set(parasol_list)
parasol_list_ordered = [ks_id for ks_id in ks_unit_ids_sorted if ks_id in parasol_set]

# %% [markdown]
# ### Generate EIs from original file for the parasol list

# %%
from extract_data_snippets import extract_snippets
import numpy as np
import h5py

# not baseline corrected!

# --- Parameters ---
window = (-60, 90)
n_channels = 512
dtype = 'int16'

# Path to raw data
dat_path_orig = '/Volumes/Lab/Users/alexth/axolotl/201703151_data001.dat'

# Output file path
ei_save_path = '/Volumes/Lab/Users/alexth/axolotl/201703151_data001_parasol_eis.h5'

with h5py.File(ei_save_path, 'w') as f:
    for ks_id in parasol_list_ordered:
        spike_times = all_spikes[ks_id]

        # Remove ISI violations (refractory < 60 samples)
        cleaned_spikes = [spike_times[0]]
        for t in spike_times[1:]:
            if t - cleaned_spikes[-1] >= 60:
                cleaned_spikes.append(t)
        cleaned_spikes = np.array(cleaned_spikes)

        print(f"Removed {len(spike_times) - len(cleaned_spikes)} spikes from unit {ks_id}")

        snips = extract_snippets(dat_path_orig, cleaned_spikes, window=window, n_channels=n_channels, dtype=dtype)
        ei = np.mean(snips, axis=2)  # shape: [512 x T]
        f.create_dataset(f'unit_{ks_id}', data=ei)
# Out:
# Removed 1 spikes from unit 54
# Removed 3 spikes from unit 187
# Removed 6 spikes from unit 801
# Removed 0 spikes from unit 265
# Removed 8 spikes from unit 216
# Removed 12 spikes from unit 648
# Removed 2 spikes from unit 337
# Removed 2 spikes from unit 124
# Removed 1 spikes from unit 157
# Removed 11 spikes from unit 440
# Removed 0 spikes from unit 6
# Removed 169 spikes from unit 179
# Removed 3 spikes from unit 386
# Removed 1 spikes from unit 856
# Removed 0 spikes from unit 596
# Removed 7 spikes from unit 190
# Removed 2 spikes from unit 158
# Removed 0 spikes from unit 766
# Removed 4 spikes from unit 649
# Removed 0 spikes from unit 297
# Removed 0 spikes from unit 132
# Removed 13 spikes from unit 534
# Removed 0 spikes from unit 315
# Removed 17 spikes from unit 584
# Removed 9 spikes from unit 438
# Removed 50 spikes from unit 253
# Removed 2 spikes from unit 350
# Removed 0 spikes from unit 196
# Removed 4 spikes from unit 258
# Removed 0 spikes from unit 716
# Removed 0 spikes from unit 141
# Removed 1 spikes from unit 97
# Removed 3 spikes from unit 800
# Removed 2 spikes from unit 619
# Removed 2 spikes from unit 813
# Removed 5 spikes from unit 563
# Removed 7 spikes from unit 477
# Removed 2 spikes from unit 851
# Removed 20 spikes from unit 539
# Removed 1 spikes from unit 147
# Removed 3 spikes from unit 63
# Removed 0 spikes from unit 403
# Removed 12 spikes from unit 526
# Removed 0 spikes from unit 447
# Removed 4 spikes from unit 364
# Removed 0 spikes from unit 617
# Removed 19 spikes from unit 659
# Removed 42 spikes from unit 597
# Removed 2 spikes from unit 17
# Removed 6 spikes from unit 434
# Removed 17 spikes from unit 687
# Removed 4 spikes from unit 251
# Removed 16 spikes from unit 620
# Removed 4 spikes from unit 26
# Removed 20 spikes from unit 439
# Removed 0 spikes from unit 289
# Removed 39 spikes from unit 693
# Removed 4 spikes from unit 409
# Removed 1 spikes from unit 428
# Removed 0 spikes from unit 330
# Removed 111 spikes from unit 69
# Removed 2 spikes from unit 168
# Removed 8 spikes from unit 48
# Removed 12 spikes from unit 379
# Removed 2 spikes from unit 229
# Removed 16 spikes from unit 116
# Removed 1 spikes from unit 323
# Removed 3 spikes from unit 199
# Removed 0 spikes from unit 70
# Removed 9 spikes from unit 342
# Removed 1 spikes from unit 65
# Removed 21 spikes from unit 363
# Removed 10 spikes from unit 266
# Removed 9 spikes from unit 678
# Removed 358 spikes from unit 505
# Removed 2 spikes from unit 349
# Removed 1 spikes from unit 383
# Removed 2 spikes from unit 644
# Removed 0 spikes from unit 286
# Removed 4 spikes from unit 713
# Removed 0 spikes from unit 322
# Removed 4 spikes from unit 551
# Removed 5 spikes from unit 544
# Removed 3 spikes from unit 176
# Removed 3 spikes from unit 76
# Removed 2 spikes from unit 252
# Removed 29 spikes from unit 513
# Removed 1 spikes from unit 373
# Removed 30 spikes from unit 99
# Removed 1 spikes from unit 269
# Removed 2 spikes from unit 655
# Removed 73 spikes from unit 46
# Removed 6 spikes from unit 182
# Removed 23 spikes from unit 669
# Removed 13 spikes from unit 487
# Removed 7 spikes from unit 15
# Removed 0 spikes from unit 507
# Removed 3 spikes from unit 193
# Removed 18 spikes from unit 558
# Removed 0 spikes from unit 80
# Removed 9 spikes from unit 272
# Removed 16 spikes from unit 167
# Removed 7 spikes from unit 472
# Removed 10 spikes from unit 155
# Removed 12 spikes from unit 234
# Removed 14 spikes from unit 779
# Removed 12 spikes from unit 206
# Removed 9 spikes from unit 781
# Removed 73 spikes from unit 788
# Removed 31 spikes from unit 415
# Removed 0 spikes from unit 646
# Removed 1 spikes from unit 603
# Removed 17 spikes from unit 594
# Removed 1 spikes from unit 806
# Removed 3 spikes from unit 183
# Removed 9 spikes from unit 610
# Removed 1 spikes from unit 581
# Removed 10 spikes from unit 479
# Removed 0 spikes from unit 20
# Removed 0 spikes from unit 101
# Removed 4 spikes from unit 462
# Removed 5 spikes from unit 696

# %% [markdown]
# ### subtract one by one and plot results

# %%
import prepare_subtraction_templates
import importlib
importlib.reload(prepare_subtraction_templates)
import subtract_unit_from_raw
importlib.reload(subtract_unit_from_raw)
from extract_data_snippets import extract_snippets
import numpy as np
import h5py
import matplotlib.pyplot as plt
from plot_ei_waveforms import plot_ei_waveforms  # assuming this is already imported
import os

# --- Parameters ---s
window = (-60, 90)
n_channels = 512
dtype = 'int16'
template_window = (-20, 60)
subtraction_window = (-10, 30)
EI_threshold = 10
n_bins = 3
template_center = 20
total_samples = 36_000_000  # adjust as needed

dat_path = '/Volumes/Lab/Users/alexth/axolotl/201703151_data001_sub.dat'
ei_mod_path = '/Volumes/Lab/Users/alexth/axolotl/201703151_data001_parasol_eis_mod.h5'
ei_sub_path = '/Volumes/Lab/Users/alexth/axolotl/201703151_data001_parasol_eis_sub.h5'
ei_orig_path = '/Volumes/Lab/Users/alexth/axolotl/201703151_data001_parasol_eis.h5'
save_dir = '/Volumes/Lab/Users/alexth/axolotl/201703151_parasol_ei_WVs'
os.makedirs(save_dir, exist_ok=True)

with h5py.File(ei_mod_path, 'w') as f_mod, h5py.File(ei_sub_path, 'w') as f_sub:
    for ks_id in parasol_list_ordered:
        spike_times = all_spikes[ks_id]

        # Remove ISI violations (<60 samples apart)
        cleaned_spikes = [spike_times[0]]
        for t in spike_times[1:]:
            if t - cleaned_spikes[-1] >= 60:
                cleaned_spikes.append(t)
        cleaned_spikes = np.array(cleaned_spikes)
        print(f"Removed {len(spike_times) - len(cleaned_spikes)} spikes from unit {ks_id}")

        # --- EI before subtraction ---
        snips_mod = extract_snippets(dat_path, cleaned_spikes, window=window, n_channels=n_channels, dtype=dtype)
        ei_mod = np.mean(snips_mod, axis=2)
        ei_mod -= ei_mod[:, :5].mean(axis=1, keepdims=True)
        f_mod.create_dataset(f'unit_{ks_id}', data=ei_mod)

        print(ks_id)

        # Load original EI
        with h5py.File(ei_orig_path, 'r') as f_orig:
            ei_orig = f_orig[f'unit_{ks_id}'][:]
            ei_orig -= ei_orig[:, :5].mean(axis=1, keepdims=True)


        ei_ptp = ei_orig.max(axis=1) - ei_orig.min(axis=1)
        ref_channel = np.argmax(ei_ptp)
        ref_waveform = ei_orig[ref_channel]
        true_peak_sample = np.argmin(ref_waveform)  # sample index of negative deflection
        expected_center = 60  # center of (-60, 90) window
        align_shift = true_peak_sample - expected_center

        if align_shift != 0:
            print(f"Adjusting spike times by {align_shift} samples (soma peak at {true_peak_sample})")
            spike_times_aligned = cleaned_spikes.copy()
            spike_times_aligned = spike_times_aligned + align_shift
        else:
            spike_times_aligned = cleaned_spikes.copy()


        # --- Get templates ---
        ei_template, ei_channels, x_shifts, templates_by_chan, template_ids_by_chan, y_shifts_by_chan = prepare_subtraction_templates.prepare_subtraction_templates(
            dat_path=dat_path,
            spike_times=spike_times_aligned,
            EI_threshold=EI_threshold,
            window=template_window,
            max_lag=3,
            n_bins=n_bins,
            n_channels=n_channels,
            dtype=dtype,
            subtraction_window=(10, 50),
            save_dir=save_dir,
            ks_id=ks_id
        )

        # --- Subtract ---
        subtract_unit_from_raw.subtract_unit_from_raw(
            dat_path=dat_path,
            spike_times=spike_times_aligned,
            x_shifts=x_shifts,
            templates=templates_by_chan,
            template_ids=template_ids_by_chan,
            ei_waveform=ei_template,
            unit_id=ks_id,
            target_channels=ei_channels,
            start_sample=0,
            total_samples=total_samples,
            template_center=template_center,
            subtraction_window=subtraction_window,
            n_channels=n_channels,
            dtype=dtype
        )

        # --- EI after subtraction ---
        snips_sub = extract_snippets(dat_path, cleaned_spikes, window=window, n_channels=n_channels, dtype=dtype)
        ei_sub = np.mean(snips_sub, axis=2)
        ei_sub -= ei_sub[:, :5].mean(axis=1, keepdims=True)
        f_sub.create_dataset(f'unit_{ks_id}', data=ei_sub)



        # Plot and save
        plt.figure(figsize=(20, 20))
        plot_ei_waveforms([ei_orig, ei_mod, ei_sub], ei_positions,
                        colors=['black', 'red', 'blue'], scale=70, box_height=1.0, box_width=50)

        plt.title(f"Unit {ks_id} | Removed {len(spike_times) - len(cleaned_spikes)} spikes", fontsize=16)
        save_path = os.path.join(save_dir, f'unit_{ks_id}.png')
        plt.savefig(save_path, bbox_inches='tight', pad_inches=0.1, dpi=150)

        plt.close()
# Out:
# Removed 1 spikes from unit 54
# 54
# Adjusting spike times by -8 samples (soma peak at 52)
# 23 18
# Unit 54 subtraction complete.
# Removed 3 spikes from unit 187
# 187
# Adjusting spike times by -1 samples (soma peak at 59)
# 23 18
# Unit 187 subtraction complete.
# Removed 6 spikes from unit 801
# 801
# Adjusting spike times by -14 samples (soma peak at 46)
# 23 18
# Unit 801 subtraction complete.
# Removed 0 spikes from unit 265
# 265
# Adjusting spike times by -7 samples (soma peak at 53)
# 23 18
# Unit 265 subtraction complete.
# Removed 8 spikes from unit 216
# 216
# Adjusting spike times by -1 samples (soma peak at 59)
# 23 18
# Unit 216 subtraction complete.
# Removed 12 spikes from unit 648
# 648
# 17 23
# Unit 648 subtraction complete.
# Removed 2 spikes from unit 337
# 337
# Adjusting spike times by -1 samples (soma peak at 59)
# 24 18
# Unit 337 subtraction complete.
# Removed 2 spikes from unit 124
# 124
# Adjusting spike times by -1 samples (soma peak at 59)
# 23 18
# Unit 124 subtraction complete.
# Removed 1 spikes from unit 157
# 157
# Adjusting spike times by -7 samples (soma peak at 53)
# 17 24
# Unit 157 subtraction complete.
# Removed 11 spikes from unit 440
# 440
# Adjusting spike times by -1 samples (soma peak at 59)
# 23 18
# Unit 440 subtraction complete.
# Removed 0 spikes from unit 6
# 6
# 23 18
# Unit 6 subtraction complete.
# Removed 169 spikes from unit 179
# 179
# Adjusting spike times by -1 samples (soma peak at 59)
# 23 18
# Unit 179 subtraction complete.
# Removed 3 spikes from unit 386
# 386
# Adjusting spike times by -1 samples (soma peak at 59)
# 24 17
# Unit 386 subtraction complete.
# Removed 1 spikes from unit 856
# 856
# Adjusting spike times by -7 samples (soma peak at 53)
# 23 18
# Unit 856 subtraction complete.
# Removed 0 spikes from unit 596
# 596
# 22 18
# Unit 596 subtraction complete.
# Removed 7 spikes from unit 190
# 190
# Adjusting spike times by -1 samples (soma peak at 59)
# 23 17
# Unit 190 subtraction complete.
# Removed 2 spikes from unit 158
# 158
# Adjusting spike times by -1 samples (soma peak at 59)
# 18 24
# Unit 158 subtraction complete.
# Removed 0 spikes from unit 766
# 766
# 23 17
# Unit 766 subtraction complete.
# Removed 4 spikes from unit 649
# 649
# Adjusting spike times by -1 samples (soma peak at 59)
# 17 24
# Unit 649 subtraction complete.
# Removed 0 spikes from unit 297
# 297
# 18 22
# Unit 297 subtraction complete.
# Removed 0 spikes from unit 132
# 132
# 23 17
# Unit 132 subtraction complete.
# Removed 13 spikes from unit 534
# 534
# Adjusting spike times by -1 samples (soma peak at 59)
# 23 18
# Unit 534 subtraction complete.
# Removed 0 spikes from unit 315
# 315
# 22 18
# Unit 315 subtraction complete.
# Removed 17 spikes from unit 584
# 584
# Adjusting spike times by -1 samples (soma peak at 59)
# 24 18
# Unit 584 subtraction complete.
# Removed 9 spikes from unit 438
# 438
# Adjusting spike times by -1 samples (soma peak at 59)
# 24 18
# Unit 438 subtraction complete.
# Removed 50 spikes from unit 253
# 253
# Adjusting spike times by -3 samples (soma peak at 57)
# 18 22
# Unit 253 subtraction complete.
# Removed 2 spikes from unit 350
# 350
# 22 18
# Unit 350 subtraction complete.
# Removed 0 spikes from unit 196
# 196
# Adjusting spike times by -15 samples (soma peak at 45)
# 23 17
# Unit 196 subtraction complete.
# Removed 4 spikes from unit 258
# 258
# 23 18
# Unit 258 subtraction complete.
# Removed 0 spikes from unit 716
# 716
# 23 17
# Unit 716 subtraction complete.
# Removed 0 spikes from unit 141
# 141
# Adjusting spike times by -1 samples (soma peak at 59)
# 22 17
# Unit 141 subtraction complete.
# Removed 1 spikes from unit 97
# 97
# 18 23
# Unit 97 subtraction complete.
# Removed 3 spikes from unit 800
# 800
# Adjusting spike times by 1 samples (soma peak at 61)
# Unit 800 subtraction complete.
# Removed 2 spikes from unit 619
# 619
# Adjusting spike times by -1 samples (soma peak at 59)
# 18 23
# Unit 619 subtraction complete.
# Removed 2 spikes from unit 813
# 813
# Adjusting spike times by -18 samples (soma peak at 42)
# 18 23
# Unit 813 subtraction complete.
# Removed 5 spikes from unit 563
# 563
# Adjusting spike times by -1 samples (soma peak at 59)
# 23 18
# Unit 563 subtraction complete.
# Removed 7 spikes from unit 477
# 477
# Adjusting spike times by -1 samples (soma peak at 59)
# 17 23
# Unit 477 subtraction complete.
# Removed 2 spikes from unit 851
# 851
# Adjusting spike times by -1 samples (soma peak at 59)
# 18 23
# Unit 851 subtraction complete.
# Removed 20 spikes from unit 539
# 539
# Adjusting spike times by -1 samples (soma peak at 59)
# 23 18
# Unit 539 subtraction complete.
# Removed 1 spikes from unit 147
# 147
# Adjusting spike times by -16 samples (soma peak at 44)
# 23 18
# Unit 147 subtraction complete.
# Removed 3 spikes from unit 63
# 63
# 23 18
# Unit 63 subtraction complete.
# Removed 0 spikes from unit 403
# 403
# Adjusting spike times by -1 samples (soma peak at 59)
# 23 18
# Unit 403 subtraction complete.
# Removed 12 spikes from unit 526
# 526
# 17 22
# Unit 526 subtraction complete.
# Removed 0 spikes from unit 447
# 447
# Adjusting spike times by -1 samples (soma peak at 59)
# 23 18
# Unit 447 subtraction complete.
# Removed 4 spikes from unit 364
# 364
# Adjusting spike times by -1 samples (soma peak at 59)
# 18 22
# Unit 364 subtraction complete.
# Removed 0 spikes from unit 617
# 617
# 17 22
# Unit 617 subtraction complete.
# Removed 19 spikes from unit 659
# 659
# 22 17
# Unit 659 subtraction complete.
# Removed 42 spikes from unit 597
# 597
# 23 18
# Unit 597 subtraction complete.
# Removed 2 spikes from unit 17
# 17
# Adjusting spike times by -3 samples (soma peak at 57)
# 18 22
# Unit 17 subtraction complete.
# Removed 6 spikes from unit 434
# 434
# Adjusting spike times by -2 samples (soma peak at 58)
# 18 23
# Unit 434 subtraction complete.
# Removed 17 spikes from unit 687
# 687
# Adjusting spike times by -1 samples (soma peak at 59)
# 17 23
# Unit 687 subtraction complete.
# Removed 4 spikes from unit 251
# 251
# 17 22
# Unit 251 subtraction complete.
# Removed 16 spikes from unit 620
# 620
# Adjusting spike times by -2 samples (soma peak at 58)
# 17 23
# Unit 620 subtraction complete.
# Removed 4 spikes from unit 26
# 26
# 23 18
# Unit 26 subtraction complete.
# Removed 20 spikes from unit 439
# 439
# Adjusting spike times by -1 samples (soma peak at 59)
# 17 24
# Unit 439 subtraction complete.
# Removed 0 spikes from unit 289
# 289
# 18 23
# Unit 289 subtraction complete.
# Removed 39 spikes from unit 693
# 693
# 18 22
# Unit 693 subtraction complete.
# Removed 4 spikes from unit 409
# 409
# Adjusting spike times by -1 samples (soma peak at 59)
# 24 16
# Unit 409 subtraction complete.
# Removed 1 spikes from unit 428
# 428
# Adjusting spike times by -1 samples (soma peak at 59)
# 23 18
# Unit 428 subtraction complete.
# Removed 0 spikes from unit 330
# 330
# Adjusting spike times by -2 samples (soma peak at 58)
# Unit 330 subtraction complete.
# Removed 111 spikes from unit 69
# 69
# Adjusting spike times by -18 samples (soma peak at 42)
# 20 32
# Unit 69 subtraction complete.
# Removed 2 spikes from unit 168
# 168
# 22 17
# Unit 168 subtraction complete.
# Removed 8 spikes from unit 48
# 48
# Adjusting spike times by -2 samples (soma peak at 58)
# 17 23
# Unit 48 subtraction complete.
# Removed 12 spikes from unit 379
# 379
# Adjusting spike times by -1 samples (soma peak at 59)
# 19 22
# Unit 379 subtraction complete.
# Removed 2 spikes from unit 229
# 229
# 18 23
# Unit 229 subtraction complete.
# Removed 16 spikes from unit 116
# 116
# Adjusting spike times by 1 samples (soma peak at 61)
# 17 22
# Unit 116 subtraction complete.
# Removed 1 spikes from unit 323
# 323
# Adjusting spike times by -2 samples (soma peak at 58)
# Unit 323 subtraction complete.
# Removed 3 spikes from unit 199
# 199
# Adjusting spike times by -2 samples (soma peak at 58)
# 23 18
# Unit 199 subtraction complete.
# Removed 0 spikes from unit 70
# 70
# Adjusting spike times by -2 samples (soma peak at 58)
# 18 22
# Unit 70 subtraction complete.
# Removed 9 spikes from unit 342
# 342
# Adjusting spike times by 1 samples (soma peak at 61)
# Unit 342 subtraction complete.
# Removed 1 spikes from unit 65
# 65
# Adjusting spike times by -8 samples (soma peak at 52)
# 23 17
# Unit 65 subtraction complete.
# Removed 21 spikes from unit 363
# 363
# Unit 363 subtraction complete.
# Removed 10 spikes from unit 266
# 266
# 22 18
# Unit 266 subtraction complete.
# Removed 9 spikes from unit 678
# 678
# Adjusting spike times by -1 samples (soma peak at 59)
# 18 23
# Unit 678 subtraction complete.
# Removed 358 spikes from unit 505
# 505
# Adjusting spike times by -1 samples (soma peak at 59)
# Unit 505 subtraction complete.
# Removed 2 spikes from unit 349
# 349
# 18 22
# Unit 349 subtraction complete.
# Removed 1 spikes from unit 383
# 383
# 18 22
# Unit 383 subtraction complete.
# Removed 2 spikes from unit 644
# 644
# Adjusting spike times by 16 samples (soma peak at 76)
# 18 22
# Unit 644 subtraction complete.
# Removed 0 spikes from unit 286
# 286
# 17 22
# Unit 286 subtraction complete.
# Removed 4 spikes from unit 713
# 713
# 23 18
# Unit 713 subtraction complete.
# Removed 0 spikes from unit 322
# 322
# Adjusting spike times by -1 samples (soma peak at 59)
# 18 23
# Unit 322 subtraction complete.
# Removed 4 spikes from unit 551
# 551
# 17 24
# Unit 551 subtraction complete.
# Removed 5 spikes from unit 544
# 544
# Adjusting spike times by -1 samples (soma peak at 59)
# 18 23
# Unit 544 subtraction complete.
# Removed 3 spikes from unit 176
# 176
# Adjusting spike times by -1 samples (soma peak at 59)
# 24 18
# Unit 176 subtraction complete.
# Removed 3 spikes from unit 76
# 76
# 18 23
# Unit 76 subtraction complete.
# Removed 2 spikes from unit 252
# 252
# 18 22
# Unit 252 subtraction complete.
# Removed 29 spikes from unit 513
# 513
# Adjusting spike times by -1 samples (soma peak at 59)
# 18 24
# Unit 513 subtraction complete.
# Removed 1 spikes from unit 373
# 373
# Adjusting spike times by -1 samples (soma peak at 59)
# 18 23
# Unit 373 subtraction complete.
# Removed 30 spikes from unit 99
# 99
# 18 23
# Unit 99 subtraction complete.
# Removed 1 spikes from unit 269
# 269
# 18 21
# Unit 269 subtraction complete.
# Removed 2 spikes from unit 655
# 655
# Adjusting spike times by 17 samples (soma peak at 77)
# 17 15
# Unit 655 subtraction complete.
# Removed 73 spikes from unit 46
# 46
# 22 17
# Unit 46 subtraction complete.
# Removed 6 spikes from unit 182
# 182
# Adjusting spike times by -1 samples (soma peak at 59)
# 23 18
# Unit 182 subtraction complete.
# Removed 23 spikes from unit 669
# 669
# 18 23
# Unit 669 subtraction complete.
# Removed 13 spikes from unit 487
# 487
# Adjusting spike times by -1 samples (soma peak at 59)
# 17 24
# Unit 487 subtraction complete.
# Removed 7 spikes from unit 15
# 15
# Adjusting spike times by -2 samples (soma peak at 58)
# 18 22
# Unit 15 subtraction complete.
# Removed 0 spikes from unit 507
# 507
# Adjusting spike times by -3 samples (soma peak at 57)
# 18 22
# Unit 507 subtraction complete.
# Removed 3 spikes from unit 193
# 193
# Adjusting spike times by -2 samples (soma peak at 58)
# Unit 193 subtraction complete.
# Removed 18 spikes from unit 558
# 558
# 18 22
# Unit 558 subtraction complete.
# Removed 0 spikes from unit 80
# 80
# Adjusting spike times by 9 samples (soma peak at 69)
# Unit 80 subtraction complete.
# Removed 9 spikes from unit 272
# 272
# 18 22
# Unit 272 subtraction complete.
# Removed 16 spikes from unit 167
# 167
# Adjusting spike times by 4 samples (soma peak at 64)
# Unit 167 subtraction complete.
# Removed 7 spikes from unit 472
# 472
# 18 23
# Unit 472 subtraction complete.
# Removed 10 spikes from unit 155
# 155
# Adjusting spike times by -1 samples (soma peak at 59)
# 18 23
# Unit 155 subtraction complete.
# Removed 12 spikes from unit 234
# 234
# 18 22
# Unit 234 subtraction complete.
# Removed 14 spikes from unit 779
# 779
# 18 16
# Unit 779 subtraction complete.
# Removed 12 spikes from unit 206
# 206
# Adjusting spike times by -1 samples (soma peak at 59)
# 23 18
# Unit 206 subtraction complete.
# Removed 9 spikes from unit 781
# 781
# Adjusting spike times by 7 samples (soma peak at 67)
# Unit 781 subtraction complete.
# Removed 73 spikes from unit 788
# 788
# Adjusting spike times by -3 samples (soma peak at 57)
# Unit 788 subtraction complete.
# Removed 31 spikes from unit 415
# 415
# Unit 415 subtraction complete.
# Removed 0 spikes from unit 646
# 646
# Adjusting spike times by -1 samples (soma peak at 59)
# Unit 646 subtraction complete.
# Removed 1 spikes from unit 603
# 603
# Adjusting spike times by 3 samples (soma peak at 63)
# 18 22
# Unit 603 subtraction complete.
# Removed 17 spikes from unit 594
# 594
# Adjusting spike times by -1 samples (soma peak at 59)
# 22 18
# Unit 594 subtraction complete.
# Removed 1 spikes from unit 806
# 806
# Unit 806 subtraction complete.
# Removed 3 spikes from unit 183
# 183
# Adjusting spike times by -1 samples (soma peak at 59)
# Unit 183 subtraction complete.
# Removed 9 spikes from unit 610
# 610
# Adjusting spike times by 8 samples (soma peak at 68)
# Unit 610 subtraction complete.
# Removed 1 spikes from unit 581
# 581
# Unit 581 subtraction complete.
# Removed 10 spikes from unit 479
# 479
# Adjusting spike times by 8 samples (soma peak at 68)
# Unit 479 subtraction complete.
# Removed 0 spikes from unit 20
# 20
# Adjusting spike times by -3 samples (soma peak at 57)
# Unit 20 subtraction complete.
# Removed 0 spikes from unit 101
# 101
# Unit 101 subtraction complete.
# Removed 4 spikes from unit 462
# 462
# Adjusting spike times by 9 samples (soma peak at 69)
# Unit 462 subtraction complete.
# Removed 5 spikes from unit 696
# 696
# Unit 696 subtraction complete.
